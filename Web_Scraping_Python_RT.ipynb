# %% [markdown]
# ## Using Web Scraping to Gather Rotten Tomatoes Data

# %%
from bs4 import BeautifulSoup as bs
import os
import pandas as pd

# %%
df_list = []
# createing a variable folder to store the html files
folder = 'rt_html'

# iterating through the items of the folder
for movie_html in os.listdir(folder):
    with open(os.path.join(folder, movie_html)) as file:
        # setting up lxml parser
        soup = bs(file, 'lxml')
        title = soup.find('title').contents[0][:-len(' - Rotten Tomatoes')]
        audience_score = soup.find('div', class_ = 'audience-score meter').find('span', class_="superPageFontColor").contents[0][:-1]
        num_audience_ratings = soup.find('div', class_="audience-info hidden-xs superPageFontColor")
        num_audience_ratings = num_audience_ratings.find_all('div')[1].contents[2].strip().replace(',', '')
        
        # appending data to list of dictionaries
        df_list.append({'title': title,
                        'audience_score': int(audience_score),
                        'number_of_audience_ratings': int(num_audience_ratings)})
# creating dataframe
df = pd.DataFrame(df_list, columns = ['title', 'audience_score', 'number_of_audience_ratings'])

# %%
df
# Out:
#                                                 title  audience_score  \
# 0                                      Dunkirk (2017)              82
# 1                        The Last Picture Show (1971)              90
# 2                              The Dark Knight (2008)              94
# 3                      The Night of the Hunter (1955)              90
# 4                             Sunset Boulevard (1950)              95
# 5                               Apocalypse Now (1979)              94
# 6                                    Star Trek (2009)              91
# 7                                  Man on Wire (2008)              87
# 8                                      Get Out (2017)              87
# 9                             12 Years a Slave (2013)              90
# 10                                        Argo (2012)              90
# 11                                      Psycho (1960)              94
# ...
